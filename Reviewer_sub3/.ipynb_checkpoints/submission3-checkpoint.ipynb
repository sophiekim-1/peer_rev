# %%
# Preliminaries -----------------------------------------------------------
if (!require("pacman")) install.packages("pacman")
pacman::p_load(tidyverse, ggplot2, dplyr, lubridate, haven)

# %%
final.hcris <- read_tsv("../data/output/HCRIS_Data.txt")
# Out:
# Rows: 161060 Columns: 44
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr   (9): provider_number, data_source, street, city, state, zip, county, n...
# dbl  (31): beds, tot_charges, net_pat_rev, tot_discounts, tot_operating_exp,...
# date  (4): fy_start, fy_end, date_processed, date_created
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# price variables
new.final.hcris <- final.hcris %>% 
  mutate(
    discount_factor = 1-tot_discounts/tot_charges,
    price_num = (ip_charges + icu_charges + ancillary_charges)*discount_factor - tot_mcare_payment,
    price_denom = tot_discharges - mcare_discharges,
    est_price = price_num/price_denom
  ) %>% 
  mutate(est_price = ifelse(est_price < 0, NA, est_price)) %>% # set negative prices to NA
  mutate(
    p99 = quantile(est_price, 0.99, na.rm = TRUE), # drop outlier prices
    p01 = quantile(est_price, 0.01, na.rm = TRUE),
    est_price = ifelse(est_price < p01 | est_price > p99, NA, est_price)) %>% 
  drop_na(est_price) %>%
  select(-p99, -p01) %>%
  mutate(
    hvbp_payment = ifelse(is.na(hvbp_payment), 0, hvbp_payment),
    hrrp_payment = ifelse(is.na(hrrp_payment), 0, abs(hrrp_payment))
  )

# penalty calculations
net_penalty <- new.final.hcris %>% 
  filter(year == 2012) %>% 
  mutate(net_penalty = hvbp_payment - hrrp_payment) %>% 
  select(provider_number, net_penalty)

# price change
price_change <- new.final.hcris %>% 
  filter(year %in% c(2011, 2014)) %>% 
  select(provider_number, year, est_price) %>% 
  pivot_wider(names_from = year, values_from = est_price, names_prefix = "price_") %>% 
  mutate(price_change = price_2014 - price_2011) %>% 
  select(provider_number, price_change)

# pre-2012 variables
pre_2012 <- new.final.hcris %>%
  filter(year %in% c(2009:2011)) %>%
  group_by(provider_number) %>%
  summarize(
    mean_mcare = mean(mcare_discharges, na.rm = TRUE),
    mean_beds = mean(beds, na.rm = TRUE),
    mean_mcaid = mean(mcaid_discharges, na.rm = TRUE)
  ) %>% ungroup()

# merge data for price change
merged_data <- price_change %>% 
  inner_join(net_penalty, by = "provider_number") %>% 
  inner_join(pre_2012, by = "provider_number") %>% 
  filter (!is.na(price_change), !is.na(net_penalty), 
     !is.na(mean_mcare),!is.na(mean_mcaid))  

new.final.hcris %>% 
  filter(source =="weighted_average")
# Out:
#     provider_number fy_start   fy_end     date_processed date_created
# 1   010012          2023-04-01 2024-12-31 2025-06-06     2025-06-03
# 2   010016          2009-10-01 2010-12-31 2011-06-28     2011-02-25
# 3   010024          2009-07-01 2010-12-31 2014-10-22     2011-01-25
# 4   010034          2002-07-01 2003-09-30 2005-03-15     2004-10-13
# 5   010038          2016-07-01 2017-09-30 2018-11-14     2018-03-20
# 6   010046          2014-07-01 2015-12-31 2016-07-25     2015-10-23
# 7   010054          2010-07-01 2011-12-31 2014-07-23     2013-11-12
# 8   010055          2013-07-01 2014-09-30 2015-03-20     2014-12-17
# 9   010059          2008-03-01 2009-09-30 2013-06-07     2010-04-07
# 10  010064          2005-07-01 2006-12-31 2013-03-26     2012-10-23
# 11  010069          2005-04-01 2006-12-31 2009-02-09     2008-02-11
# 12  010069          2016-10-01 2017-11-30 2018-11-20     2018-03-19
# 13  010079          2014-07-01 2015-12-31 2016-10-26     2015-12-10
# 14  010086          2013-05-01 2014-12-31 2015-09-16     2014-10-08
# 15  010089          2009-07-01 2010-12-31 2015-04-30     2011-02-28
# 16  010090          2022-07-01 2023-09-30 2025-02-25     2024-03-28
# 17  010098          2002-10-01 2003-12-31 2005-12-14     2005-08-16
# 18  010101          2009-07-01 2010-12-31 2011-06-23     2011-03-02
# 19  010103          2009-07-01 2010-12-31 2011-06-13     2010-12-13
# 20  010104          2004-07-01 2005-09-30 2017-08-10     2008-05-08
# 21  010118          2000-07-01 2001-09-30 2005-08-23     2003-09-23
# 22  010125          2013-05-01 2014-12-31 2015-10-15     2014-10-09
# 23  010126          2009-04-01 2010-12-31 2014-08-27     2013-05-17
# 24  010150          2016-02-01 2017-10-31 2018-11-14     2018-10-30
# 25  010152          2011-04-01 2012-10-31 2014-06-24     2013-05-30
# 26  010157          2000-07-01 2001-12-31 2004-03-05     2003-08-26
# 27  010157          2009-04-01 2010-06-30 2010-12-14     2010-09-22
# 28  010158          2000-07-01 2001-12-31 2003-09-26     2003-06-19
# 29  020004          2005-07-01 2006-08-20 2008-02-28     2007-12-26
# 30  020006          2004-06-01 2005-12-31 2010-09-23     2007-02-05
# ⋮   ⋮               ⋮          ⋮          ⋮              ⋮
# 879 510026          2008-07-01 2009-09-20 2013-05-17     2010-02-22
# 880 510031          2006-08-01 2007-09-30 2013-03-06     2012-11-28
# 881 510033          2006-02-01 2007-12-31 2013-03-06     2012-11-27
# 882 510038          2021-07-01 2022-12-31 2025-03-31     2023-11-03
# 883 510058          2010-07-01 2011-12-31 2014-10-24     2014-01-27
# 884 510061          2003-07-01 2004-08-31 2007-12-05     2006-09-26
# 885 510068          2004-10-01 2005-12-14 2008-12-18     2007-09-25
# 886 510071          2009-07-01 2010-09-30 2015-02-10     2012-02-07
# 887 520011          2019-10-01 2020-12-31 2025-03-20     2021-05-05
# 888 520037          2016-07-01 2017-09-30 2018-11-16     2018-03-22
# 889 520037          2019-10-01 2020-12-31 2025-04-30     2021-05-06
# 890 520042          2003-10-01 2004-12-31 2007-02-14     2006-09-23
# 891 520053          1999-10-01 2000-12-31 2005-04-20     2004-09-09
# 892 520060          2004-10-01 2005-11-30 2009-12-28     2009-12-15
# 893 520069          1998-07-01 1999-09-30 2002-09-27     2001-08-26
# 894 520076          2019-07-01 2020-12-31 2021-12-07     2021-11-12
# 895 520088          2017-07-01 2018-12-31 2022-04-27     2018-12-27
# 896 520091          2002-04-01 2003-09-30 2006-10-16     2006-05-23
# 897 520103          2000-10-01 2001-12-31 2006-12-08     2004-09-10
# 898 520114          2003-07-01 2004-09-30 2007-09-24     2006-09-27
# 899 520134          2002-07-01 2003-09-30 2008-09-09     2006-08-08
# 900 520152          2000-04-01 2001-09-30 2004-08-26     2003-08-26
# 901 520202          2019-07-01 2020-12-31 2022-02-11     2021-08-03
# 902 530007          2002-07-01 2003-10-31 2005-10-17     2005-10-14
# 903 530011          2023-07-01 2024-12-05 2025-04-16     2024-11-06
# 904 530012          2019-07-01 2020-12-31 2021-12-17     2021-09-02
# 905 530025          2016-07-01 2017-12-31 2018-11-20     2018-10-12
# 906 670031          2009-07-01 2010-12-31 2013-02-06     2012-01-27
# 907 670068          2016-04-01 2017-12-31 2018-12-21     2018-06-30
# 908 670079          2015-04-01 2016-08-31 2018-12-20     2016-10-14
#     data_source beds tot_charges net_pat_rev tot_discounts ⋯
# 1   NA           97   446571221   44472717   402098504     ⋯
# 2   NA          192   657038543  113702136   543336407     ⋯
# 3   NA          255   500669906  130967576   369702330     ⋯
# 4   NA           69    25572712   15486963    10085749     ⋯
# 5   NA          125   344555341   28487742   316067599     ⋯
# 6   NA          256   760393609   76556213   683837396     ⋯
# 7   NA          109   240108319   36395607   203712711     ⋯
# 8   NA          235   993595674  164610765   828984910     ⋯
# 9   NA           37    39132994   13855009    25277986     ⋯
# 10  NA          185   270836859   87819682   183017177     ⋯
# 11  NA           74    51181325   13345290    37836035     ⋯
# 12  NA           30    57159865   16794505    40365359     ⋯
# 13  NA          101   183548287   45594913   137953374     ⋯
# 14  NA           61    91958079   19727163    72230916     ⋯
# 15  NA          139   303894976   61754155   242140821     ⋯
# 16  NA          349   827744823  209586358   618158465     ⋯
# 17  NA           49    10389850    5424842     4965008     ⋯
# 18  NA           82   140532402   29597129   110935273     ⋯
# 19  NA          269  1092733860  170174976   922558884     ⋯
# 20  NA          319   864743520  181905172   682838348     ⋯
# 21  NA          130    62616439   23816260    38800179     ⋯
# 22  NA           50    41049061   11378570    29670491     ⋯
# 23  NA           97   100336023   32243119    68092904     ⋯
# 24  NA           44   130872919   14728675   116144244     ⋯
# 25  NA          124    97540332   25495843    72044489     ⋯
# 26  NA          128    66224732   20236295    45988437     ⋯
# 27  NA          122    91102021   24214047    66887974     ⋯
# 28  NA          100    48492855   16930667    31562188     ⋯
# 29  NA           35    55802264   39281360    16520905     ⋯
# 30  NA           40    89776999   60933817    28843182     ⋯
# ⋮   ⋮           ⋮    ⋮           ⋮           ⋮             ⋱
# 879 NA           51    58036697   22688811    35347886     ⋯
# 880 NA          145   166801731   69730049    97071682     ⋯
# 881 NA          184   193018831   94698820    98320010     ⋯
# 882 NA           49   128479073   40099577    88379496     ⋯
# 883 NA          407   428235154  160741808   267493346     ⋯
# 884 NA           63    22068098   11686688    10381410     ⋯
# 885 NA           44    50990696   29582924    21407772     ⋯
# 886 NA          137   172682442   77386259    95296183     ⋯
# 887 NA           40   293740479  131711780   162028698     ⋯
# 888 NA          286   598238386  249985744   348252643     ⋯
# 889 NA          189  1471014011  573194096   897819914     ⋯
# 890 NA           38    44137241   24679397    19457844     ⋯
# 891 NA           56    14758621   10960025     3798596     ⋯
# 892 NA           49    72044928   42959802    29085126     ⋯
# 893 NA           95    77371277   36892746    40478531     ⋯
# 894 NA           48   206095759   76643449   129452310     ⋯
# 895 NA          115   835143870  310864804   524279066     ⋯
# 896 NA           84    76830508   44916081    31914427     ⋯
# 897 NA          122   113242095   72020885    41221210     ⋯
# 898 NA           36    17361276   10904043     6457232     ⋯
# 899 NA           42    20824107   14145172     6678935     ⋯
# 900 NA           39    42206478   26647335    15559143     ⋯
# 901 NA           99   200261426   78297629   121963797     ⋯
# 902 NA           38    21466035   15234323     6231712     ⋯
# 903 NA           58   227853673  107071502   120782171     ⋯
# 904 NA          226   500311197  228359632   271951566     ⋯
# 905 NA           66   129226502   73343388    55883114     ⋯
# 906 NA           61   182794678   45852246   136942431     ⋯
# 907 NA          103   379871706  149022212   230849494     ⋯
# 908 NA          106   290335080   57950507   232384572     ⋯
#     tot_uncomp_care_charges tot_uncomp_care_partial_pmts bad_debt
# 1            NA                      NA                        NA
# 2            NA                      NA                        NA
# 3            NA                      NA                        NA
# 4            NA                      NA                        NA
# 5    1885443.76                13.36264                  16439362
# 6      33211.07              1198.93967                  33613448
# 7    3359662.40                      NA                   5295437
# 8    8527145.40              4886.80000                  19245854
# 9            NA                      NA                        NA
# 10           NA                      NA                        NA
# 11           NA                      NA                        NA
# 12    525298.43               217.19811                   2508587
# 13   2762586.12                      NA                   3450649
# 14           NA                      NA                   4606990
# 15           NA                      NA                        NA
# 16  37879858.40                      NA                  11041322
# 17           NA                      NA                        NA
# 18           NA                      NA                        NA
# 19           NA                      NA                        NA
# 20           NA                      NA                        NA
# 21           NA                      NA                        NA
# 22     68970.62                10.83553                   3759199
# 23           NA                      NA                        NA
# 24   1245742.44             36288.72841                   5206803
# 25    608745.45             58929.25260                  11301491
# 26           NA                      NA                        NA
# 27           NA                      NA                        NA
# 28           NA                      NA                        NA
# 29           NA                      NA                        NA
# 30           NA                      NA                        NA
# ⋮   ⋮                       ⋮                            ⋮
# 879         NA                      NA                           NA
# 880         NA                      NA                           NA
# 881         NA                      NA                           NA
# 882  1164279.9                      NA                     663717.1
# 883 17110028.0                      NA                    6786913.6
# 884         NA                      NA                           NA
# 885         NA                      NA                           NA
# 886         NA                      NA                           NA
# 887   986198.3                      NA                     830587.8
# 888  5567394.0              1131864.00                    4608430.4
# 889  6088915.3                      NA                    8974366.0
# 890         NA                      NA                           NA
# 891         NA                      NA                           NA
# 892         NA                      NA                           NA
# 893         NA                      NA                           NA
# 894  2364373.1                28141.84                    3174048.1
# 895  1096980.2                25628.82                    7697693.5
# 896         NA                      NA                           NA
# 897         NA                      NA                           NA
# 898         NA                      NA                           NA
# 899         NA                      NA                           NA
# 900         NA                      NA                           NA
# 901  2026970.9                      NA                    4011339.2
# 902         NA                      NA                           NA
# 903         NA                      NA                           NA
# 904 14344284.1                39491.36                   20547999.8
# 905  1046165.9                      NA                    3433421.4
# 906         NA                      NA                           NA
# 907  8582141.2                80159.36                    9398473.7
# 908         NA                      NA                   13393222.6
#     accum_dep    year source           discount_factor price_num   price_denom
# 1     1806603.35 2024 weighted_average 0.09958706       8570723.8  1929.5399
# 2    93907434.60 2010 weighted_average 0.17305246      41382867.9  5900.2000
# 3   129361378.51 2010 weighted_average 0.26158468      42407697.9  6660.7660
# 4     2408632.60 2003 weighted_average 0.60560502       2042364.1   799.2000
# 5     2153016.98 2017 weighted_average 0.08267973       2778963.8  1024.9011
# 6    24754006.34 2015 weighted_average 0.10067972      19684065.0  2897.1920
# 7     4231281.40 2011 weighted_average 0.15157995       8975795.3  1949.8208
# 8   106152995.40 2014 weighted_average 0.16567178      42002987.9  5123.8000
# 9     1625843.65 2009 weighted_average 0.35404928       1181498.1   702.4419
# 10  136973539.33 2006 weighted_average 0.32425307      38656567.1  2116.0183
# 11     349376.10 2006 weighted_average 0.26074529       1708810.2   513.6865
# 12    3727595.23 2017 weighted_average 0.29381639       1680699.9   470.1792
# 13   54233900.84 2015 weighted_average 0.24840827       3687943.1  2223.4132
# 14   17199498.88 2014 weighted_average 0.21452343       1947831.6   492.5395
# 15   34186668.43 2010 weighted_average 0.20320887      15147619.0  2958.8099
# 16  204468176.80 2023 weighted_average 0.25320165      75977590.2  9046.4000
# 17    5348084.40 2003 weighted_average 0.52212903        882708.8   311.2000
# 18   19844378.25 2010 weighted_average 0.21060715       3915563.8  1805.3327
# 19  147282111.40 2010 weighted_average 0.15573323      51608071.6  6100.8373
# 20  592674452.80 2005 weighted_average 0.21035737      65461865.0  6921.2000
# 21      75565.78 2001 weighted_average 0.38035156       3859203.8  2191.8791
# 22   10116085.89 2014 weighted_average 0.27719440       1115504.8   446.3750
# 23     383157.14 2010 weighted_average 0.32135138       4782462.1  1106.4357
# 24   10622787.53 2017 weighted_average 0.11254181       1772295.1   341.7268
# 25    7084709.32 2012 weighted_average 0.26138770       5730728.3   984.1090
# 26   80345366.33 2001 weighted_average 0.30557006       2564474.0  1261.9799
# 27  154909608.41 2010 weighted_average 0.26579045       7015733.5   517.6564
# 28   80345366.33 2001 weighted_average 0.34913734       3992538.5  1767.7112
# 29   14395781.57 2006 weighted_average 0.70393845      10477993.5  1124.6280
# 30    4315259.22 2005 weighted_average 0.67872414      17820015.9  1650.7868
# ⋮   ⋮            ⋮    ⋮                ⋮               ⋮           ⋮
# 879  20238871.7  2009 weighted_average 0.3909390         4107521.2  886.7483
# 880          NA  2007 weighted_average 0.4180415        10461348.0 1755.3302
# 881   1801342.7  2007 weighted_average 0.4906196        29164149.8 3234.0373
# 882  28904826.6  2022 weighted_average 0.3121098         5954201.3  862.3894
# 883 260231431.1  2011 weighted_average 0.3753587        41294435.3 5828.3291
# 884   6554279.4  2004 weighted_average 0.5295739          881902.8  325.8897
# 885  15281737.3  2005 weighted_average 0.5801632         3857742.7  975.2694
# 886  70921676.0  2010 weighted_average 0.4481420        13729632.1 2738.0000
# 887  48427287.1  2020 weighted_average 0.4483951         8045231.4 1006.8026
# 888   1046959.2  2017 weighted_average 0.4178698       124909816.8 6434.6000
# 889 532169381.6  2020 weighted_average 0.3896592       136309652.3 6427.8969
# 890  13877818.4  2004 weighted_average 0.5591513         5295290.4  844.3487
# 891   6748519.1  2000 weighted_average 0.7426185         1602495.4  437.7478
# 892  22721839.2  2005 weighted_average 0.5962918         5643261.9  599.4528
# 893  38874501.0  1999 weighted_average 0.4768274        10616221.2 1413.0000
# 894 113984029.3  2020 weighted_average 0.3718827         9563513.5  777.3923
# 895 233038602.6  2018 weighted_average 0.3722290        50153070.3 3337.5905
# 896  32880347.7  2003 weighted_average 0.5846126        14849256.7 1576.0000
# 897  31845871.0  2001 weighted_average 0.6359904        29789135.7 4398.8000
# 898   7449789.2  2004 weighted_average 0.6280669         1996113.7  236.4978
# 899   8421270.0  2003 weighted_average 0.6792691         3567225.5  447.2000
# 900  13329604.7  2001 weighted_average 0.6313565         6625998.2  703.0000
# 901 167428830.2  2020 weighted_average 0.3909771        28901695.3 2376.8321
# 902    802658.9  2003 weighted_average 0.7096943         2444326.1  617.8930
# 903 123386437.9  2024 weighted_average 0.4699134        11321630.3 1026.0632
# 904 267986631.9  2020 weighted_average 0.4564352        86902350.3 3728.0000
# 905  56854594.7  2017 weighted_average 0.5675569        12322588.1  804.6691
# 906  15923161.7  2010 weighted_average 0.2508402        10320991.0 1719.3205
# 907  33341445.1  2017 weighted_average 0.3922962        55764954.2 4001.8495
# 908  22845547.7  2016 weighted_average 0.1995987        20192249.3 1269.8046
#     est_price
# 1    4441.848
# 2    7013.808
# 3    6366.790
# 4    2555.511
# 5    2711.446
# 6    6794.187
# 7    4603.395
# 8    8197.624
# 9    1681.987
# 10  18268.541
# 11   3326.562
# 12   3574.594
# 13   1658.685
# 14   3954.671
# 15   5119.497
# 16   8398.655
# 17   2836.468
# 18   2168.888
# 19   8459.178
# 20   9458.167
# 21   1760.683
# 22   2499.031
# 23   4322.404
# 24   5186.292
# 25   5823.266
# 26   2032.104
# 27  13552.877
# 28   2258.592
# 29   9316.853
# 30  10794.862
# ⋮   ⋮
# 879  4632.116
# 880  5959.761
# 881  9017.877
# 882  6904.307
# 883  7085.124
# 884  2706.139
# 885  3955.566
# 886  5014.475
# 887  7990.872
# 888 19412.212
# 889 21205.949
# 890  6271.450
# 891  3660.773
# 892  9414.022
# 893  7513.249
# 894 12302.042
# 895 15026.730
# 896  9422.117
# 897  6772.105
# 898  8440.305
# 899  7976.801
# 900  9425.317
# 901 12159.755
# 902  3955.905
# 903 11034.047
# 904 23310.716
# 905 15313.858
# 906  6002.948
# 907 13934.795
# 908 15901.855

# %% [markdown]
# After creating the datasets, I calculated the estimated price using hospital cost report variables, and removed negative prices and observations in the bottom and top 1% to address outliers. I then constructed the data for questions 6-10. Price changes from 2011 to 2014 were calculated with simply subtracting the price from each year. Net penalty was a difference between hvbp and hrrp payment, and pre-period averages of Medicare discharges, bed size, and Medicaid discharges from 2009 to 2011 were also calculated.

# %% [markdown]
# ## Problem 1
#
# The number of hospitals filing more than one report does not decline over time, suggesting that there is not a significant improvement

# %%
final.hcris %>% 
  group_by(source, year) %>% 
  filter((source == "total for year")|(source == "weighted_average"))%>%
  group_by(year) %>% 
  summarize("counts" = n()) %>% 
  filter(year >= 2009, year <= 2019) %>%
  ggplot(aes(x = as.factor(year), y = counts)) +
  geom_line(group=1) +
  geom_point() + 
  labs(
       x = "Year",
       y = "Number of Hospitals")
# Out:
# plot without title

# %% [markdown]
# ## Problem 2
#
# There are consistently around 7,000 unique hospital IDs per year.

# %%
options(knitr.kable.NA = 0)
library(knitr)
library(kableExtra)

final.hcris %>%
  mutate(year = year(fy_end)) %>%
  filter(year >= 2009, year <= 2019) %>%
  group_by(year) %>%
  summarise(unique_hospitals = n_distinct(provider_number)) %>%
  kable(
    col.names = c("Year", "Unique Hospitals"),
    booktabs  = TRUE,
    caption   = "Unique Hospital IDs by Year"
  ) %>%
  kable_styling(latex_options = c("hold_position", "striped")) %>%
  column_spec(1, bold = TRUE) %>%
  row_spec(0, bold = TRUE)
# Out:
# <table class="table" style="margin-left: auto; margin-right: auto;">
# <caption>Unique Hospital IDs by Year</caption>
#  <thead>
#   <tr>
#    <th style="text-align:right;font-weight: bold;"> Year </th>
#    <th style="text-align:right;font-weight: bold;"> Unique Hospitals </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:right;font-weight: bold;"> 2009 </td>
#    <td style="text-align:right;"> 6100 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;font-weight: bold;"> 2010 </td>
#    <td style="text-align:right;"> 6103 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;font-weight: bold;"> 2011 </td>
#    <td style="text-align:right;"> 6097 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;font-weight: bold;"> 2012 </td>
#    <td style="text-align:right;"> 6140 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;font-weight: bold;"> 2013 </td>
#    <td style="text-align:right;"> 6066 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;font-weight: bold;"> 2014 </td>
#    <td style="text-align:right;"> 6064 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;font-weight: bold;"> 2015 </td>
#    <td style="text-align:right;"> 6051 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;font-weight: bold;"> 2016 </td>
#    <td style="text-align:right;"> 6091 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;font-weight: bold;"> 2017 </td>
#    <td style="text-align:right;"> 6083 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;font-weight: bold;"> 2018 </td>
#    <td style="text-align:right;"> 6042 </td>
#   </tr>
#   <tr>
#    <td style="text-align:right;font-weight: bold;"> 2019 </td>
#    <td style="text-align:right;"> 6035 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Problem 3
#
# Total charges increased steadily from 2009-2019, which reflects growth in hospital billing across all hospital sizes.

# %%
new.final.hcris %>%
  mutate(year = year(fy_end)) %>%
  filter(year >= 2009, year <= 2019) %>%
  filter(tot_charges > 0) %>%
  ggplot(aes(x = factor(year), y = tot_charges)) +
  geom_violin() +
  stat_summary(fun = "mean", geom = "point", color = "red", size = 2) +
  stat_summary(fun = "mean", geom = "line", aes(group = 1), color = "red") +
  scale_y_log10(labels = scales::label_log(digits = 2)) +
  labs(
    title = "Distribution of total charges by year",
    x = "Year",
    y = "Total charges (log scale)"
  ) +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# ## Problem 4
#
# Estimated prices show an upward trend from 2009-2019, with a large variation across hospitals each year. The distribution centers around $10,000 per discharge.

# %%
new.final.hcris %>%
  mutate(
    year = year(fy_end),
    discount_factor = 1 - tot_discounts / tot_charges,
    price_num = (ip_charges + icu_charges + ancillary_charges) * discount_factor - tot_mcare_payment,
    price_denom = tot_discharges - mcare_discharges,
    price = price_num / price_denom
  ) %>%
  filter(year >= 2009, year <= 2019) %>%
  ggplot(aes(x = factor(year), y = est_price)) +
  geom_violin() +
  stat_summary(fun = "mean", geom = "point", color = "red", size = 2) +
  stat_summary(fun = "mean", geom = "line", aes(group = 1), color = "red") +
  scale_y_continuous(labels = scales::comma) +
  labs(
    title = "Distribution of estimated hospital prices by year",
    x = "Year",
    y = "Estimated price"
  ) +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# ## Problem 5
#
# The share of hospitals penalized under HRRP/VBP rose sharply from 2012 to 2013 and remained relatively stable around 70% through 2019. The sharp increase can be attributed to the HRRP/VBP being instilled from 2010 with the Affordable Care Act.

# %%
new.final.hcris %>%
  mutate(
    year = year(fy_end),
    penalty = as.numeric((hvbp_payment - hrrp_payment) < 0)
  ) %>%
  filter(year >= 2012, year <= 2019) %>%
  group_by(year) %>%
  summarise(share_penalized = mean(penalty, na.rm = TRUE)) %>%
  
ggplot(aes(x = year, y = share_penalized)) +
  geom_line() +
  geom_point() +
  scale_y_continuous(labels = scales::percent, limits = c(0, 1)) +
  labs(
    title = "Share of hospitals penalized under HRRP/VBP",
    x = "Year",
    y = "Share penalized"
  ) +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# ## Problem 6
# This table presents OLS estimates of the effect of net penalties on price changes across three different specifications. The coefficient on net penalty is small and negative across all specifications, which suggests slightly lower price growth in penalized hospitals, but this could be due to the endogeneity issue of penalty status.

# %%
ols1 <- lm(price_change ~ net_penalty, data = merged_data)
ols2 <- lm(price_change ~ net_penalty + mean_beds, data = merged_data)
ols3 <- lm(price_change ~ net_penalty + mean_beds + mean_mcaid, data = merged_data)

summary(ols1)
summary(ols2)
summary(ols3)
# Out:
# Call:
# lm(formula = price_change ~ net_penalty, data = merged_data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -21473.9  -1237.7    -70.7   1200.7  21762.6
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) 218.034431  55.164241   3.952 7.96e-05 ***
# net_penalty  -0.003641   0.001357  -2.684  0.00733 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2625 on 2393 degrees of freedom
# Multiple R-squared:  0.003001,	Adjusted R-squared:  0.002585
# F-statistic: 7.203 on 1 and 2393 DF,  p-value: 0.007327
# Call:
# lm(formula = price_change ~ net_penalty + mean_beds, data = merged_data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -21462.6  -1229.8    -65.4   1197.3  21755.1
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) 200.004335  55.741717   3.588  0.00034 ***
# net_penalty  -0.003542   0.001356  -2.611  0.00907 **
# mean_beds     0.074318   0.034183   2.174  0.02980 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2623 on 2392 degrees of freedom
# Multiple R-squared:  0.004967,	Adjusted R-squared:  0.004135
# F-statistic: 5.971 on 2 and 2392 DF,  p-value: 0.002591
# Call:
# lm(formula = price_change ~ net_penalty + mean_beds + mean_mcaid,
#     data = merged_data)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -21420  -1240    -47   1204  21679
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 39.258417  68.247916   0.575   0.5652
# net_penalty -0.002931   0.001360  -2.154   0.0313 *
# mean_beds    0.064588   0.034158   1.891   0.0588 .
# mean_mcaid   0.102904   0.025370   4.056 5.15e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2614 on 2391 degrees of freedom
# Multiple R-squared:  0.01177,	Adjusted R-squared:  0.01053
# F-statistic:  9.49 on 3 and 2391 DF,  p-value: 3.129e-06

# %%
fmt_p <- function(p) ifelse(is.na(p), NA, sprintf("%.3f", p))

data.frame(
  Statistic = c(
    "Intercept", "p-value",
    "Net Penalty", "p-value",
    "Mean Beds (Pre-2012)", "p-value",
    "Mean Medicaid Discharges (Pre-2012)", "p-value",
    "# Obs", "R2"
  ),
  `OLS 1` = c(
    round(coef(ols1)["(Intercept)"], 3),
    fmt_p(coef(summary(ols1))["(Intercept)", "Pr(>|t|)"]),
    round(coef(ols1)["net_penalty"], 3),
    fmt_p(coef(summary(ols1))["net_penalty", "Pr(>|t|)"]),
    NA, NA, NA, NA,
    nobs(ols1), round(summary(ols1)$r.squared, 3)
  ),
  `OLS 2` = c(
    round(coef(ols2)["(Intercept)"], 3),
    fmt_p(coef(summary(ols2))["(Intercept)", "Pr(>|t|)"]),
    round(coef(ols2)["net_penalty"], 3),
    fmt_p(coef(summary(ols2))["net_penalty", "Pr(>|t|)"]),
    round(coef(ols2)["mean_beds"], 3),
    fmt_p(coef(summary(ols2))["mean_beds", "Pr(>|t|)"]),
    NA, NA,
    nobs(ols2), round(summary(ols2)$r.squared, 3)
  ),
  `OLS 3` = c(
    round(coef(ols3)["(Intercept)"], 3),
    fmt_p(coef(summary(ols3))["(Intercept)", "Pr(>|t|)"]),
    round(coef(ols3)["net_penalty"], 3),
    fmt_p(coef(summary(ols3))["net_penalty", "Pr(>|t|)"]),
    round(coef(ols3)["mean_beds"], 3),
    fmt_p(coef(summary(ols3))["mean_beds", "Pr(>|t|)"]),
    round(coef(ols3)["mean_mcaid"], 3),
    fmt_p(coef(summary(ols3))["mean_mcaid", "Pr(>|t|)"]),
    nobs(ols3), round(summary(ols3)$r.squared, 3)
  ),
  check.names = FALSE
) %>%
  kable(
    col.names = c("Statistic", "OLS 1", "OLS 2", "OLS 3"),
    digits = 3, booktabs = TRUE,
    caption = "OLS Estimates of Net Penalty on Price Changes"
  ) %>%
  kable_styling(latex_options = c("hold_position", "striped")) %>%
  column_spec(1, bold = TRUE) %>%
  row_spec(0, bold = TRUE) %>%
  row_spec(c(2, 4, 6, 8), italic = TRUE, color = "gray") %>%
  pack_rows("Coefficients", 1, 8) %>%
  pack_rows("Model Fit", 9, 10)
# Out:
# <table class="table" style="margin-left: auto; margin-right: auto;">
# <caption>OLS Estimates of Net Penalty on Price Changes</caption>
#  <thead>
#   <tr>
#    <th style="text-align:left;font-weight: bold;"> Statistic </th>
#    <th style="text-align:left;font-weight: bold;"> OLS 1 </th>
#    <th style="text-align:left;font-weight: bold;"> OLS 2 </th>
#    <th style="text-align:left;font-weight: bold;"> OLS 3 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr grouplength="8"><td colspan="4" style="border-bottom: 1px solid;"><strong>Coefficients</strong></td></tr>
# <tr>
#    <td style="text-align:left;font-weight: bold;padding-left: 2em;" indentlevel="1"> Intercept </td>
#    <td style="text-align:left;"> 218.034 </td>
#    <td style="text-align:left;"> 200.004 </td>
#    <td style="text-align:left;"> 39.258 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;font-style: italic;color: gray !important;padding-left: 2em;" indentlevel="1"> p-value </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.000 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.000 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.565 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;padding-left: 2em;" indentlevel="1"> Net Penalty </td>
#    <td style="text-align:left;"> -0.004 </td>
#    <td style="text-align:left;"> -0.004 </td>
#    <td style="text-align:left;"> -0.003 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;font-style: italic;color: gray !important;padding-left: 2em;" indentlevel="1"> p-value </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.007 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.009 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.031 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;padding-left: 2em;" indentlevel="1"> Mean Beds (Pre-2012) </td>
#    <td style="text-align:left;"> 0 </td>
#    <td style="text-align:left;"> 0.074 </td>
#    <td style="text-align:left;"> 0.065 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;font-style: italic;color: gray !important;padding-left: 2em;" indentlevel="1"> p-value </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.030 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.059 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;padding-left: 2em;" indentlevel="1"> Mean Medicaid Discharges (Pre-2012) </td>
#    <td style="text-align:left;"> 0 </td>
#    <td style="text-align:left;"> 0 </td>
#    <td style="text-align:left;"> 0.103 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;font-style: italic;color: gray !important;padding-left: 2em;" indentlevel="1"> p-value </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.000 </td>
#   </tr>
#   <tr grouplength="2"><td colspan="4" style="border-bottom: 1px solid;"><strong>Model Fit</strong></td></tr>
# <tr>
#    <td style="text-align:left;font-weight: bold;padding-left: 2em;" indentlevel="1"> # Obs </td>
#    <td style="text-align:left;"> 2395 </td>
#    <td style="text-align:left;"> 2395 </td>
#    <td style="text-align:left;"> 2395 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;padding-left: 2em;" indentlevel="1"> R2 </td>
#    <td style="text-align:left;"> 0.003 </td>
#    <td style="text-align:left;"> 0.005 </td>
#    <td style="text-align:left;"> 0.012 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Problem 7
# The scatterplot shows a negative relationship between net penalty and pre-2012 Medicare discharges. This suggests that hospitals with a larger proportion of Medicare patient tended to receive larger net penalties.

# %%
ggplot(merged_data, aes(x = mean_mcare, y = net_penalty)) +
  geom_point(alpha = 0.3) +
  scale_x_continuous(labels = scales::comma) +
  scale_y_continuous(labels = scales::comma) +
  labs(
    title = "Net penalty vs pre-2012 Medicare discharges",
    x = "Average Medicare discharges (2009-2011)",
    y = "Net penalty (2012)"
  ) +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# ## Problem 8
# The first stage shows a strong negative relationship between pre-2012 Medicare discharges and net penalty. This confirms that Medicare discharge share is a good instrument. The reduced form shows a weaker but direct relationship between Medicare discharges and price changes.

# %%
library(fixest)

# First stage: net_penalty with mean_mcare as instrument
fs1 <- feols(net_penalty ~ mean_mcare, data = merged_data)
fs2 <- feols(net_penalty ~ mean_mcare + mean_beds, data = merged_data)
fs3 <- feols(net_penalty ~ mean_mcare + mean_beds + mean_mcaid, data = merged_data)

# Reduced form: price_change with mean_mcare as instrument
rf1 <- feols(price_change ~ mean_mcare, data = merged_data)
rf2 <- feols(price_change ~ mean_mcare + mean_beds, data = merged_data)
rf3 <- feols(price_change ~ mean_mcare + mean_beds + mean_mcaid, data = merged_data)

cat("=== First Stage ===\n")
summary(fs1)
summary(fs2)
summary(fs3)

cat("=== Reduced Form ===\n")
summary(rf1)
summary(rf2)
summary(rf3)
# Out:
# === First Stage ===
# OLS estimation, Dep. Var.: net_penalty
# Observations: 2,395
# Standard-errors: IID
#               Estimate  Std. Error   t value   Pr(>|t|)
# (Intercept) 6128.38525 1167.581876   5.24878 1.6658e-07 ***
# mean_mcare    -4.27618    0.242429 -17.63891  < 2.2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# RMSE: 37,195.4   Adj. R2: 0.114688
# OLS estimation, Dep. Var.: net_penalty
# Observations: 2,395
# Standard-errors: IID
#                Estimate  Std. Error    t value   Pr(>|t|)
# (Intercept) 6126.161155 1168.285315   5.243720 1.7117e-07 ***
# mean_mcare    -4.277878    0.243771 -17.548744  < 2.2e-16 ***
# mean_beds      0.033047    0.487367   0.067808 9.4594e-01
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# RMSE: 37,195.3   Adj. R2: 0.114319
# OLS estimation, Dep. Var.: net_penalty
# Observations: 2,395
# Standard-errors: IID
#                Estimate  Std. Error    t value   Pr(>|t|)
# (Intercept) 5566.745704 1178.923149   4.721890 2.4718e-06 ***
# mean_mcare    -4.714854    0.278687 -16.918073  < 2.2e-16 ***
# mean_beds     -0.008497    0.486590  -0.017462 9.8607e-01
# mean_mcaid     1.319282    0.410348   3.215035 1.3217e-03 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# RMSE: 37,115.2   Adj. R2: 0.117763
# === Reduced Form ===
# OLS estimation, Dep. Var.: price_change
# Observations: 2,395
# Standard-errors: IID
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) 170.112064  82.458136 2.06301 0.039219 *
# mean_mcare    0.022576   0.017121 1.31860 0.187427
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# RMSE: 2,626.8   Adj. R2: 3.085e-4
# OLS estimation, Dep. Var.: price_change
# Observations: 2,395
# Standard-errors: IID
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) 165.168781  82.429317 2.00376 0.045208 *
# mean_mcare    0.018798   0.017199 1.09297 0.274518
# mean_beds     0.073451   0.034387 2.13604 0.032778 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# RMSE: 2,624.3   Adj. R2: 0.001795
# OLS estimation, Dep. Var.: price_change
# Observations: 2,395
# Standard-errors: IID
#               Estimate Std. Error  t value   Pr(>|t|)
# (Intercept) 112.057792  83.033998  1.34954 1.7729e-01
# mean_mcare   -0.022688   0.019629 -1.15588 2.4785e-01
# mean_beds     0.069507   0.034272  2.02812 4.2659e-02 *
# mean_mcaid    0.125253   0.028902  4.33376 1.5265e-05 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# RMSE: 2,614.1   Adj. R2: 0.00916

# %%
fmt_p <- function(p) ifelse(is.na(p), NA, sprintf("%.5f", p))
get_coef <- function(m, v) { ct <- coef(m); if(v %in% names(ct)) round(ct[v],3) else NA }
get_p <- function(m, v) { pt <- coeftable(m)[,"Pr(>|t|)"]; if(v %in% names(pt)) fmt_p(pt[v]) else NA }

i <- "(Intercept)"; mc <- "mean_mcare"; mb <- "mean_beds"; mid <- "mean_mcaid"

data.frame(
  Statistic = c("Intercept","p-value","Avg Medicare","p-value","Mean Beds","p-value","Mean Medicaid","p-value","# Obs","R2"),
  `FS 1` = c(get_coef(fs1,i),get_p(fs1,i),get_coef(fs1,mc),get_p(fs1,mc),NA,NA,NA,NA,nobs(fs1),round(r2(fs1,"r2"),3)),
  `FS 2` = c(get_coef(fs2,i),get_p(fs2,i),get_coef(fs2,mc),get_p(fs2,mc),get_coef(fs2,mb),get_p(fs2,mb),NA,NA,nobs(fs2),round(r2(fs2,"r2"),3)),
  `FS 3` = c(get_coef(fs3,i),get_p(fs3,i),get_coef(fs3,mc),get_p(fs3,mc),get_coef(fs3,mb),get_p(fs3,mb),get_coef(fs3,mid),get_p(fs3,mid),nobs(fs3),round(r2(fs3,"r2"),3)),
  `RF 1` = c(get_coef(rf1,i),get_p(rf1,i),get_coef(rf1,mc),get_p(rf1,mc),NA,NA,NA,NA,nobs(rf1),round(r2(rf1,"r2"),3)),
  `RF 2` = c(get_coef(rf2,i),get_p(rf2,i),get_coef(rf2,mc),get_p(rf2,mc),get_coef(rf2,mb),get_p(rf2,mb),NA,NA,nobs(rf2),round(r2(rf2,"r2"),3)),
  `RF 3` = c(get_coef(rf3,i),get_p(rf3,i),get_coef(rf3,mc),get_p(rf3,mc),get_coef(rf3,mb),get_p(rf3,mb),get_coef(rf3,mid),get_p(rf3,mid),nobs(rf3),round(r2(rf3,"r2"),3)),
  check.names = FALSE
) %>%
  kable(col.names=c("Statistic","FS 1","FS 2","FS 3","RF 1","RF 2","RF 3"),digits=3,booktabs=TRUE,caption="First Stage and Reduced Form Results") %>%
  kable_styling(latex_options=c("hold_position","striped")) %>%
  column_spec(1,bold=TRUE) %>%
  row_spec(0,bold=TRUE) %>%
  row_spec(c(2,4,6,8),italic=TRUE,color="gray") %>%
  add_header_above(c(" "=1,"First Stage"=3,"Reduced Form"=3)) %>%
  pack_rows("Coefficients",1,8) %>%
  pack_rows("Model Fit",9,10)
# Out:
# <table class="table" style="margin-left: auto; margin-right: auto;">
# <caption>First Stage and Reduced Form Results</caption>
#  <thead>
# <tr>
# <th style="empty-cells: hide;border-bottom:hidden;" colspan="1"></th>
# <th style="border-bottom:hidden;padding-bottom:0; padding-left:3px;padding-right:3px;text-align: center; " colspan="3"><div style="border-bottom: 1px solid #ddd; padding-bottom: 5px; ">First Stage</div></th>
# <th style="border-bottom:hidden;padding-bottom:0; padding-left:3px;padding-right:3px;text-align: center; " colspan="3"><div style="border-bottom: 1px solid #ddd; padding-bottom: 5px; ">Reduced Form</div></th>
# </tr>
#   <tr>
#    <th style="text-align:left;font-weight: bold;"> Statistic </th>
#    <th style="text-align:left;font-weight: bold;"> FS 1 </th>
#    <th style="text-align:left;font-weight: bold;"> FS 2 </th>
#    <th style="text-align:left;font-weight: bold;"> FS 3 </th>
#    <th style="text-align:left;font-weight: bold;"> RF 1 </th>
#    <th style="text-align:left;font-weight: bold;"> RF 2 </th>
#    <th style="text-align:left;font-weight: bold;"> RF 3 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr grouplength="8"><td colspan="7" style="border-bottom: 1px solid;"><strong>Coefficients</strong></td></tr>
# <tr>
#    <td style="text-align:left;font-weight: bold;padding-left: 2em;" indentlevel="1"> Intercept </td>
#    <td style="text-align:left;"> 6128.385 </td>
#    <td style="text-align:left;"> 6126.161 </td>
#    <td style="text-align:left;"> 5566.746 </td>
#    <td style="text-align:left;"> 170.112 </td>
#    <td style="text-align:left;"> 165.169 </td>
#    <td style="text-align:left;"> 112.058 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;font-style: italic;color: gray !important;padding-left: 2em;" indentlevel="1"> p-value </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.00000 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.00000 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.00000 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.03922 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.04521 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.17729 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;padding-left: 2em;" indentlevel="1"> Avg Medicare </td>
#    <td style="text-align:left;"> -4.276 </td>
#    <td style="text-align:left;"> -4.278 </td>
#    <td style="text-align:left;"> -4.715 </td>
#    <td style="text-align:left;"> 0.023 </td>
#    <td style="text-align:left;"> 0.019 </td>
#    <td style="text-align:left;"> -0.023 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;font-style: italic;color: gray !important;padding-left: 2em;" indentlevel="1"> p-value </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.00000 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.00000 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.00000 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.18743 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.27452 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.24785 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;padding-left: 2em;" indentlevel="1"> Mean Beds </td>
#    <td style="text-align:left;"> 0 </td>
#    <td style="text-align:left;"> 0.033 </td>
#    <td style="text-align:left;"> -0.008 </td>
#    <td style="text-align:left;"> 0 </td>
#    <td style="text-align:left;"> 0.073 </td>
#    <td style="text-align:left;"> 0.07 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;font-style: italic;color: gray !important;padding-left: 2em;" indentlevel="1"> p-value </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.94594 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.98607 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.03278 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.04266 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;padding-left: 2em;" indentlevel="1"> Mean Medicaid </td>
#    <td style="text-align:left;"> 0 </td>
#    <td style="text-align:left;"> 0 </td>
#    <td style="text-align:left;"> 1.319 </td>
#    <td style="text-align:left;"> 0 </td>
#    <td style="text-align:left;"> 0 </td>
#    <td style="text-align:left;"> 0.125 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;font-style: italic;color: gray !important;padding-left: 2em;" indentlevel="1"> p-value </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.00132 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.00002 </td>
#   </tr>
#   <tr grouplength="2"><td colspan="7" style="border-bottom: 1px solid;"><strong>Model Fit</strong></td></tr>
# <tr>
#    <td style="text-align:left;font-weight: bold;padding-left: 2em;" indentlevel="1"> # Obs </td>
#    <td style="text-align:left;"> 2395 </td>
#    <td style="text-align:left;"> 2395 </td>
#    <td style="text-align:left;"> 2395 </td>
#    <td style="text-align:left;"> 2395 </td>
#    <td style="text-align:left;"> 2395 </td>
#    <td style="text-align:left;"> 2395 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;padding-left: 2em;" indentlevel="1"> R2 </td>
#    <td style="text-align:left;"> 0.115 </td>
#    <td style="text-align:left;"> 0.115 </td>
#    <td style="text-align:left;"> 0.119 </td>
#    <td style="text-align:left;"> 0.001 </td>
#    <td style="text-align:left;"> 0.003 </td>
#    <td style="text-align:left;"> 0.01 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Problem 9
# The IV estimates show the local average treatment effect of net penalties for price changes in hospitals that had affected penalty status from Medicare volume.

# %%
# IV estimates: price_change ~ net_penalty, instrumented by mean_mcare
iv1 <- feols(price_change ~ 1 | net_penalty ~ mean_mcare, data = merged_data)
iv2 <- feols(price_change ~ mean_beds | net_penalty ~ mean_mcare, data = merged_data)
iv3 <- feols(price_change ~ mean_beds + mean_mcaid | net_penalty ~ mean_mcare, data = merged_data)

summary(iv1)
summary(iv2)
summary(iv3)
# Out:
# TSLS estimation, Dep. Var.: price_change, Endo.: net_penalty, Instr.: mean_mcare
# Second stage: Dep. Var.: price_change
# Observations: 2,395
# Standard-errors: IID
#                   Estimate Std. Error  t value  Pr(>|t|)
# (Intercept)     202.466600   65.75194  3.07925 0.0020988 **
# fit_net_penalty  -0.005279    0.00400 -1.31971 0.1870594
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# RMSE: 2,624.7   Adj. R2: 0.001976
# F-test (1st stage), net_penalty: stat = 311.1     , p < 2.2e-16, on 1 and 2,393 DoF.
#                      Wu-Hausman: stat =   0.189635, p = 0.66326, on 1 and 2,392 DoF.
# TSLS estimation, Dep. Var.: price_change, Endo.: net_penalty, Instr.: mean_mcare
# Second stage: Dep. Var.: price_change
# Observations: 2,395
# Standard-errors: IID
#                   Estimate Std. Error  t value  Pr(>|t|)
# (Intercept)     192.089233  65.875117  2.91596 0.0035789 **
# fit_net_penalty  -0.004394   0.004016 -1.09416 0.2739946
# mean_beds         0.073596   0.034336  2.14343 0.0321791 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# RMSE: 2,621.5   Adj. R2: 0.003971
# F-test (1st stage), net_penalty: stat = 308.0     , p < 2.2e-16 , on 1 and 2,392 DoF.
#                      Wu-Hausman: stat =   0.050845, p = 0.821619, on 1 and 2,391 DoF.
# TSLS estimation, Dep. Var.: price_change, Endo.: net_penalty, Instr.: mean_mcare
# Second stage: Dep. Var.: price_change
# Observations: 2,395
# Standard-errors: IID
#                  Estimate Std. Error t value   Pr(>|t|)
# (Intercept)     85.270233  72.623492 1.17414 2.4046e-01
# fit_net_penalty  0.004812   0.004188 1.14892 2.5070e-01
# mean_beds        0.069548   0.034482 2.01693 4.3814e-02 *
# mean_mcaid       0.118904   0.026819 4.43355 9.6885e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# RMSE: 2,629.9   Adj. R2: -0.00288
# F-test (1st stage), net_penalty: stat = 286.2    , p < 2.2e-16 , on 1 and 2,391 DoF.
#                      Wu-Hausman: stat =   3.88295, p = 0.048894, on 1 and 2,390 DoF.

# %%
fmt_p <- function(p) ifelse(is.na(p), NA, sprintf("%.3f", p))

get_coef <- function(model, var) {
  ct <- coef(model)
  if (var %in% names(ct)) round(ct[var], 3) else NA
}
get_p <- function(model, var) {
  pt <- coeftable(model)[, "Pr(>|t|)"]
  if (var %in% names(pt)) fmt_p(pt[var]) else NA
}

data.frame(
  Statistic = c(
    "Intercept", "p-value",
    "Net Penalty (IV)", "p-value",
    "Avg Beds (Pre-2012)", "p-value",
    "Avg Medicaid Discharges (Pre-2012)", "p-value",
    "# Obs", "R2"
  ),
  `IV 1` = c(
    get_coef(iv1, "(Intercept)"), get_p(iv1, "(Intercept)"),
    get_coef(iv1, "fit_net_penalty"), get_p(iv1, "fit_net_penalty"),
    NA, NA, NA, NA,
    nobs(iv1), round(r2(iv1, "r2"), 3)
  ),
  `IV 2` = c(
    get_coef(iv2, "(Intercept)"), get_p(iv2, "(Intercept)"),
    get_coef(iv2, "fit_net_penalty"), get_p(iv2, "fit_net_penalty"),
    get_coef(iv2, "mean_beds"), get_p(iv2, "mean_beds"),
    NA, NA,
    nobs(iv2), round(r2(iv2, "r2"), 3)
  ),
  `IV 3` = c(
    get_coef(iv3, "(Intercept)"), get_p(iv3, "(Intercept)"),
    get_coef(iv3, "fit_net_penalty"), get_p(iv3, "fit_net_penalty"),
    get_coef(iv3, "mean_beds"), get_p(iv3, "mean_beds"),
    get_coef(iv3, "mean_mcaid"), get_p(iv3, "mean_mcaid"),
    nobs(iv3), round(r2(iv3, "r2"), 3)
  ),
  check.names = FALSE
) %>%
  kable(
    col.names = c("Statistic", "IV 1", "IV 2", "IV 3"),
    digits = 3, booktabs = TRUE,
    caption = "IV Estimates of Net Penalty on Price Changes"
  ) %>%
  kable_styling(latex_options = c("hold_position", "striped")) %>%
  column_spec(1, bold = TRUE) %>%
  row_spec(0, bold = TRUE) %>%
  row_spec(c(2, 4, 6, 8), italic = TRUE, color = "gray") %>%
  pack_rows("Coefficients", 1, 8) %>%
  pack_rows("Model Fit", 9, 10)
# Out:
# <table class="table" style="margin-left: auto; margin-right: auto;">
# <caption>IV Estimates of Net Penalty on Price Changes</caption>
#  <thead>
#   <tr>
#    <th style="text-align:left;font-weight: bold;"> Statistic </th>
#    <th style="text-align:left;font-weight: bold;"> IV 1 </th>
#    <th style="text-align:left;font-weight: bold;"> IV 2 </th>
#    <th style="text-align:left;font-weight: bold;"> IV 3 </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr grouplength="8"><td colspan="4" style="border-bottom: 1px solid;"><strong>Coefficients</strong></td></tr>
# <tr>
#    <td style="text-align:left;font-weight: bold;padding-left: 2em;" indentlevel="1"> Intercept </td>
#    <td style="text-align:left;"> 202.467 </td>
#    <td style="text-align:left;"> 192.089 </td>
#    <td style="text-align:left;"> 85.27 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;font-style: italic;color: gray !important;padding-left: 2em;" indentlevel="1"> p-value </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.002 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.004 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.240 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;padding-left: 2em;" indentlevel="1"> Net Penalty (IV) </td>
#    <td style="text-align:left;"> -0.005 </td>
#    <td style="text-align:left;"> -0.004 </td>
#    <td style="text-align:left;"> 0.005 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;font-style: italic;color: gray !important;padding-left: 2em;" indentlevel="1"> p-value </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.187 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.274 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.251 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;padding-left: 2em;" indentlevel="1"> Avg Beds (Pre-2012) </td>
#    <td style="text-align:left;"> 0 </td>
#    <td style="text-align:left;"> 0.074 </td>
#    <td style="text-align:left;"> 0.07 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;font-style: italic;color: gray !important;padding-left: 2em;" indentlevel="1"> p-value </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.032 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.044 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;padding-left: 2em;" indentlevel="1"> Avg Medicaid Discharges (Pre-2012) </td>
#    <td style="text-align:left;"> 0 </td>
#    <td style="text-align:left;"> 0 </td>
#    <td style="text-align:left;"> 0.119 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;font-style: italic;color: gray !important;padding-left: 2em;" indentlevel="1"> p-value </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0 </td>
#    <td style="text-align:left;font-style: italic;color: gray !important;"> 0.000 </td>
#   </tr>
#   <tr grouplength="2"><td colspan="4" style="border-bottom: 1px solid;"><strong>Model Fit</strong></td></tr>
# <tr>
#    <td style="text-align:left;font-weight: bold;padding-left: 2em;" indentlevel="1"> # Obs </td>
#    <td style="text-align:left;"> 2395 </td>
#    <td style="text-align:left;"> 2395 </td>
#    <td style="text-align:left;"> 2395 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;font-weight: bold;padding-left: 2em;" indentlevel="1"> R2 </td>
#    <td style="text-align:left;"> 0.002 </td>
#    <td style="text-align:left;"> 0.005 </td>
#    <td style="text-align:left;"> -0.002 </td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Problem 10

# %% [markdown]
# Local ATE would be the average treatment effect that are only for hospitals that were penalized because of their Medicare share. This would capture the effect of penalty status on price changes only for hospitals that were penalized from Medicare patient share, making it a narrower group than all penalized hospitals. The local effect could be larger than ATE if the hospitals within the local group is more sensitive to Medicare reimbursement changes.
